# %%
import requests
import csv
from bs4 import BeautifulSoup
import re
import json
import time
import subprocess

# %%
def save_to_csv(data, filename):
    fieldnames = ['name', 'Secured-party', 'filling-type', 'email_addresses', 'mobile_numbers']
    global names

    try:
        with open(filename, 'a', newline='', encoding='utf-8') as file:
            writer = csv.DictWriter(file, fieldnames=fieldnames)

            # Check if the file is empty (to write the header only once)
            file.seek(0, 2)
            if file.tell() == 0:
                writer.writeheader()

            # save the data to the file and add it to the set
            writer.writerow(data)
    except IOError:
        print("Error: Could not write to file.")

# %%
def get_html(first_name, last_name, company=None):
    url = f"https://www.google.com/search?q=%28intext%3A%40gmail.com+%7C+intext%3A%40icloud.com+%7C+intext%3A%40yahoo.com+%7C+intext%3A%40outlook.com+%7C+intext%3A%40hotmail.com+%29+AND+%28intext%3A%27{first_name}%27%29+AND+%28intext%3A%27{last_name}%27%29+AND+%28intext%3A%27{company}%27%29"
    response = requests.get(url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Proceed with parsing the HTML content
        html_content = response.text
    else:
        print("Failed to fetch the page. Status code:", response.status_code)
        time.sleep(5)
        stop_vpn()
        time.sleep(5)
        start_vpn()
        time.sleep(5)
        exit = True
        while exit:
            if connected_to_internet():
                break       
            else:
                sleep(5)
                
        html_content = 'skip'
        
    return html_content

# %%
def connected_to_internet(url='http://www.google.com/', timeout=5):
    try:
        _ = requests.head(url, timeout=timeout)
        return True
    except requests.ConnectionError:
        print("No internet connection available.")
    return False

# %%
def get_contact(html_content):
    
    # Regular expressions for email addresses and mobile numbers
    email_pattern = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,7}\b'
    mobile_pattern = r'\b\d{10}\b'

    # Extract email addresses and mobile numbers using the patterns
    email_addresses = re.findall(email_pattern, html_content, re.IGNORECASE)
    mobile_numbers = re.findall(mobile_pattern, html_content)
    return email_addresses, mobile_numbers

# %%
def start_vpn():
    vpn_command = "expressvpn connect"  # Replace with the actual command
    subprocess.run(vpn_command, shell=True)

def stop_vpn():
    vpn_command = "expressvpn disconnect"  # Replace with the actual command
    subprocess.run(vpn_command, shell=True)

# %%
def main():

    with open('alabama.json', 'r') as file:
        # Read each line as a separate JSON object
        json_objects = [json.loads(line) for line in file]

    # Access the parsed JSON objects
    for obj in json_objects[10:15]:
        

        if ',' in obj["name"]:
            first_name, last_name = obj["name"].split(',')[:2]
        elif ' ' in obj["name"]:
            first_name, last_name = obj["name"].split(' ')[:2]
        else:
            first_name = obj["name"]
            last_name = None

        company = obj["Secured-party"]
        filling_type = obj["filling-type"]
        
        html_content = get_html(first_name, last_name, company=company)
        if html_content == 'skip':
            continue
        email_addresses, mobile_numbers = get_contact(html_content)
        
        
        html_content = get_html(first_name, last_name, company=None)
        email_addresses_without_company, mobile_numbers_without_company = get_contact(html_content)
        
        email_addresses.extend(email_addresses_without_company)
        mobile_numbers.extend(mobile_numbers_without_company)
        print(email_addresses)
#         email_addresses = ', '.join(email_addresses)
#         mobile_numbers = ', '.join(mobile_numbers)
        obj['email_addresses'] = email_addresses
        obj['mobile_numbers'] = mobile_numbers
        
        save_to_csv(obj, f'data/alabama.csv')
        time.sleep(0.5)

# %%
if __name__ == "__main__":
    main()
# Out:
# ['mitch@mitchtsailaw.com', 'JHGenResearch-Abbott@yahoo.com']
# ['auqasmi@yahoo.com', 'report.ctassam@gmail.com', 'abshek2109@gmail.com', 'raideeksha809@gmail.com', 'auqasmi@yahoo.com', 'cmallareddy@gmail.com', 'ambuj4u@gmail.com', 'report.ctassam@gmail.com']
# ['vflinn@bricker.com', 'ellis.jen@gmail.com']
# ['judgeworcester@gmail.com', 'judgechrisedwards@hotmail.com', 'najacsc6east@gmail.com', 'sandrad0953@hotmail.com']
# ['andrew.j.cronauer@gmail.com', 'pcecala.taylorarch@gmail.com']

# %%
import pandas as pd
import numpy as np
import ast

df = pd.read_csv('florida.csv')
df
# Out:
#                        Corporate_Name Document_Number  Status  \
# 0                           LIAM, LLC    L13000051110  Active
# 1                          LIAM, INC.    P93000062372   INACT
# 2            LIAM03 MULTISERVICES INC    P23000018957  Active
# 3                        LIAM13, LLC.    L22000054821  Active
# 4              LIAM.A & COMPANY, INC.    P06000062944   INACT
# ...                               ...             ...     ...
# 27528  CAMERON CLEANING SOLUTIONS LLC    L21000289570  Active
# 27529             CAMERON CLINICS LLC    L03000036202  Active
# 27530               CAMERON-COLE, LLC    M01000001367  Active
# 27531               CAMERON COLSON PA    P19000055446  Active
# 27532               CAMERON COMBS LLC    L21000321521  Active
#
#                                          email_addresses  \
# 0      ['alessauniversal@gmail.com', 'crawfordricky95...
# 1      ['lovefromliamfoundation@gmail.com', 'kkk@gmai...
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 27528  ['nicholasfiore@gmail.com', 'nicholasfiore@gma...
# 27529                                                 []
# 27530  ['bialowitz@gmail.com', 'amhohl@yahoo.com', 'e...
# 27531  ['kallaher26@gmail.com', 'Considine_anthony@ya...
# 27532  ['ccombsrealtor@gmail.com', 'cdiehl@ulct.org',...
#
#                                           mobile_numbers
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 27528                                                 []
# 27529                                                 []
# 27530                                     ['2520062923']
# 27531                                     ['1609789453']
# 27532  []                                            ...
#
# [27533 rows x 5 columns]

# %%
df['email_addresses'] = df['email_addresses'].apply(ast.literal_eval)

df['email_addresses'][0]
# Out:
# ['alessauniversal@gmail.com',
#  'crawfordricky95@gmail.com',
#  'lmc040700@gmail.com',
#  'teddyahern@yahoo.com',
#  'permits.superservice@gmail.com',
#  'liamglazing@gmail.com']

# %%
df_full = df.explode('email_addresses', ignore_index=True)
df_full
# Out:
#           Corporate_Name Document_Number  Status  \
# 0              LIAM, LLC    L13000051110  Active
# 1              LIAM, LLC    L13000051110  Active
# 2              LIAM, LLC    L13000051110  Active
# 3              LIAM, LLC    L13000051110  Active
# 4              LIAM, LLC    L13000051110  Active
# ...                  ...             ...     ...
# 55748  CAMERON COLSON PA    P19000055446  Active
# 55749  CAMERON COLSON PA    P19000055446  Active
# 55750  CAMERON COMBS LLC    L21000321521  Active
# 55751  CAMERON COMBS LLC    L21000321521  Active
# 55752  CAMERON COMBS LLC    L21000321521  Active
#
#                       email_addresses  \
# 0           alessauniversal@gmail.com
# 1           crawfordricky95@gmail.com
# 2                 lmc040700@gmail.com
# 3                teddyahern@yahoo.com
# 4      permits.superservice@gmail.com
# ...                               ...
# 55748         linarita_14@hotmail.com
# 55749       dylanlhandley@hotmail.com
# 55750         ccombsrealtor@gmail.com
# 55751                 cdiehl@ulct.org
# 55752                njarvis@ulct.org
#
#                                           mobile_numbers
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 55748                                     ['1609789453']
# 55749                                     ['1609789453']
# 55750  []                                            ...
# 55751  []                                            ...
# 55752  []                                            ...
#
# [55753 rows x 5 columns]

# %%
df_full = df_full.drop_duplicates(keep="first", ignore_index=True)

# %%
df_full.to_csv('florida_full.csv', index=False)
